# %%
require(ISLR)
require(ggplot2)
require(tidyr)
require(MASS)
# Out:
# Loading required package: MASS

# %%
library(ISLR)
library(ggplot2)
library(tidyr)
library(MASS)

# %% [markdown]
# *lda( )* function in MASS library is used here for Linear Discriminant Analysis; it is same as the glm function we used in the previous notebook; but simpler syntax
#
#
# for getting the information about the Smarket data and simple logistic regression, refer to : https://github.com/mangne/ISLR_Chapter_4/blob/master/stock_market_predictions.ipynb

# %%
?lda

# %%
data <- ISLR::Smarket
train_data <- data[data$Year< 2005, ]
test_data <- data[data$Year==2005, ]

# %%
print(dim(train_data))
print(dim(test_data))
# Out:
# [1] 998   9
# [1] 252   9

# %%
y_actual <- test_data$Direction

# %%
model <-lda(Direction~Lag1+Lag2, data = train_data)
model
# Out:
# Call:
# lda(Direction ~ Lag1 + Lag2, data = train_data)
#
# Prior probabilities of groups:
#     Down       Up
# 0.491984 0.508016
#
# Group means:
#             Lag1        Lag2
# Down  0.04279022  0.03389409
# Up   -0.03954635 -0.03132544
#
# Coefficients of linear discriminants:
#             LD1
# Lag1 -0.6420190
# Lag2 -0.5135293

# %% [markdown]
# **Prior Probabilities (π) are 0.492 and 0.508 respectively for Lag1 and Lag2**

# %%
plot(model)
# Out:
# plot without title
